# %%
import numpy as np
import random as rnd
import cv2
import matplotlib.pyplot as plt
import math
import model

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
x, y = [], []
model.load_image('./data/IMG/center_2016_12_01_13_31_13_991.jpg', 0.5, x, y, True)
print(len(x))
for im in x:
    plt.imshow(im)
    plt.show()
# Out:
# 4

# %%
im = cv2.imread('./data/IMG/center_2016_12_01_13_31_13_991.jpg')
im = cv2.convertScaleAbs(im, alpha=1, beta=-150)
plt.imshow(im, cmap='brg')

# %%
#print(im)

# %%
#im = (im * 1 + 50) / 255

# %%
rnd.randint(0,1) * 2 -1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93b9f40035bc> in <module>()
# ----> 1 rnd.randint(0,1) * 2 -1
#
# NameError: name 'rnd' is not defined
